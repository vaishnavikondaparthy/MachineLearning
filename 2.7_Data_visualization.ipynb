# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnavikondaparthy/MachineLearning/blob/main/2.7_Data_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#scatter plot

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4]
y=[2,4,6,8]

# %%
plt.scatter(x,y)
plt.show()

# %%
#line plot

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4]
y=[2,4,6,8]

# %%
plt.plot(x,y)
plt.show()

# %%
#bar plots

# %%
categories=['A','B','C','D']
values=[3,7,2,5]

# %%
plt.bar(categories,values)
plt.show()

# %%
#pie chart

# %%
labels=['Category A','Category B','Category C']
sizes=[30,45,25]

# %%
plt.pie(sizes,labels=labels,autopct='%1.1f%%')
plt.show()
