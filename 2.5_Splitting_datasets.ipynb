# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnavikondaparthy/MachineLearning/blob/main/2.5_Splitting_datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Splitting of Dataset

# %% [markdown]
# <h2> Importing Libraries </h2>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <h2> Importing Dataset </h2>

# %%
df = pd.read_excel("/content/Salary_Dataset_02.xls")

# %%
df.head()
# Out:
#    Australia  Canada  Dubai  USA  Salary  YearsExperience  Purchased
# 0          0       0      1    0   39343              1.1          0
# 1          0       1      0    0   46205              1.3          1
# 2          0       1      0    0   37731              1.5          0
# 3          0       1      0    0   43525              2.0          0
# 4          0       0      0    1   39891              2.2          0

# %% [markdown]
# <h2> Dividing into Target and Predictor Variables </h2>

# %%
# In X we store predictor variables.
# Here X will be dataframe because it has more than one features(columns).
X = df.iloc[:,:-1]
#In y we store target variables.
#Here y will be pandas series as it has only one feature(column).
y = df.iloc[:,-1]

#Here we are using X,y as dataframe because it has nice represenatation so you can understand it without confusion.
#But you can also use X,y as numpy array by this method.
        #X = df.iloc[:,:-1].values
        #y = df.iloc[:,-1].values

# %% [markdown]
# <h2> Divide Data as Training Set and Testing Set </h2>

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2,random_state = 90)

# %%
X_train
# Out:
#     Australia  Canada  Dubai  USA  Salary  YearsExperience
# 29          0       1      0    0  121872             10.5
# 6           0       1      0    0   60150              3.0
# 20          0       1      0    0   91738              6.8
# 23          1       0      0    0  113812              8.2
# 25          1       0      0    0  105582              9.0
# 14          1       0      0    0   61111              4.5
# 8           0       0      1    0   64445              3.2
# 22          1       0      0    0  101302              7.9
# 15          0       0      0    1   67938              4.9
# 21          1       0      0    0   98273              7.1
# 9           0       0      1    0   57189              3.7
# 13          0       1      0    0   57081              4.1
# 16          0       0      0    1   66029              5.1
# 19          0       1      0    0   93940              6.0
# 11          0       0      0    1   55794              4.0
# 0           0       0      1    0   39343              1.1
# 10          0       0      1    0   63218              3.9
# 28          0       0      0    1  122391             10.3
# 5           0       0      1    0   56642              2.9
# 4           0       0      0    1   39891              2.2
# 7           1       0      0    0   54445              3.2
# 3           0       1      0    0   43525              2.0
# 18          1       0      0    0   81363              5.9
# 27          0       0      0    1  112635              9.6

# %%
X_test
# Out:
#     Australia  Canada  Dubai  USA  Salary  YearsExperience
# 17          0       1      0    0   83088              5.3
# 24          0       0      1    0  109431              8.7
# 26          0       0      1    0  116969              9.5
# 2           0       1      0    0   37731              1.5
# 1           0       1      0    0   46205              1.3
# 12          0       0      1    0   56957              4.0

# %%
y_train
# Out:
# 29    1
# 6     1
# 20    0
# 23    1
# 25    1
# 14    0
# 8     1
# 22    0
# 15    0
# 21    0
# 9     0
# 13    0
# 16    0
# 19    0
# 11    0
# 0     0
# 10    1
# 28    0
# 5     0
# 4     0
# 7     0
# 3     0
# 18    1
# 27    1
# Name: Purchased, dtype: int64

# %%
y_test
# Out:
# 17    0
# 24    0
# 26    0
# 2     0
# 1     1
# 12    1
# Name: Purchased, dtype: int64

# %%
df.columns
# Out:
# Index(['Australia', 'Canada', 'Dubai', 'USA', 'Salary', 'YearsExperience',
#        'Purchased'],
#       dtype='object')

# %%
df.shape
# Out:
# (30, 7)

# %%
df.iloc[:,-1]
# Out:
# 0     0
# 1     1
# 2     0
# 3     0
# 4     0
# 5     0
# 6     1
# 7     0
# 8     1
# 9     0
# 10    1
# 11    0
# 12    1
# 13    0
# 14    0
# 15    0
# 16    0
# 17    0
# 18    1
# 19    0
# 20    0
# 21    0
# 22    0
# 23    1
# 24    0
# 25    1
# 26    0
# 27    1
# 28    0
# 29    1
# Name: Purchased, dtype: int64

# %%
df.iloc[1,::]
# Out:
# Australia              0.0
# Canada                 1.0
# Dubai                  0.0
# USA                    0.0
# Salary             46205.0
# YearsExperience        1.3
# Purchased              1.0
# Name: 1, dtype: float64

# %%
df.iloc[:,5:]
# Out:
#     YearsExperience  Purchased
# 0               1.1          0
# 1               1.3          1
# 2               1.5          0
# 3               2.0          0
# 4               2.2          0
# 5               2.9          0
# 6               3.0          1
# 7               3.2          0
# 8               3.2          1
# 9               3.7          0
# 10              3.9          1
# 11              4.0          0
# 12              4.0          1
# 13              4.1          0
# 14              4.5          0
# 15              4.9          0
# 16              5.1          0
# 17              5.3          0
# 18              5.9          1
# 19              6.0          0
# 20              6.8          0
# 21              7.1          0
# 22              7.9          0
# 23              8.2          1
# 24              8.7          0
# 25              9.0          1
# 26              9.5          0
# 27              9.6          1
# 28             10.3          0
# 29             10.5          1

# %%
df.iloc[5:,6:]
# Out:
#     Purchased
# 5           0
# 6           1
# 7           0
# 8           1
# 9           0
# 10          1
# 11          0
# 12          1
# 13          0
# 14          0
# 15          0
# 16          0
# 17          0
# 18          1
# 19          0
# 20          0
# 21          0
# 22          0
# 23          1
# 24          0
# 25          1
# 26          0
# 27          1
# 28          0
# 29          1
